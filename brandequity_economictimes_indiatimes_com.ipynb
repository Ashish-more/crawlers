# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *

# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'brandequity_economictimes_indiatimes_com'
c = Crawl()  # creating object
cl_data = dashboard['core_web_india']

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_url = 0
unable_to_fetch_rss_page = 0
publish_source = 'brandequity.economictimes.indiatimes.com'
country = 'India'
language = 'English'
images_path = []

cat_pages = c.download_page('https://brandequity.economictimes.indiatimes.com/rss')
cat_pages = c.scrap('<table width="100%"(.*?)<aside class="sidebar">', cat_pages)

for _ in cat_pages.split('<a target="_blank" href=')[1:]:
    cat_url = c.scrap('"(.*?)"', _)
    url = c.download_page(cat_url)
    
    if url.startswith('Unable to fetch'):
        logger.info(cat_url) # writes error message with error code
        unable_to_fetch_rss_page += 1
        continue    

    for i in url.split('<item>')[1:]:

        # source_link
        source_link = c.scrap('<link>(.*?)</link>', i)
 
        # handle duplicates
        source_link_query = {'source_link':source_link}
        dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
        if dic:
            duplicate_data += 1
            continue

        time.sleep(random.randint(1,3))
        
        page = c.download_page(source_link)
        if page.startswith('Unable to fetch'):
                logger.info(page) # writes error message with error code
                unable_to_fetch_url += 1
                continue  
        
        # source_headline
        source_headline = c.scrap('<title>(.*?)</title>', i)
        source_headline = source_headline.replace("<![CDATA[","").replace("]]>","")
        
        # skip if headline not found
        if not source_headline:
            logger.info(f'Skipping due to headline {source_link}\n')
            skipped_due_to_headline += 1
            continue

        logger.info(f'Fetching {source_link}\n')
        
        # Date and time
        pub_date, publish_time = '', ''

        try:
            date_time_str = c.scrap('class="date">(.*?)IST', page) + '00' 
            date_time_str = date_time_str.replace(" ","")
            date_time_str = date_time_str.replace('Updated:','')
            date_time_str = re.sub('-|T|:','',date_time_str,flags=re.S)
            date_time_obj = datetime.strptime(date_time_str, '%B%d,%Y,%H%M%S')
            # +05:30
            ist_date_time = date_time_obj - timedelta(hours = 5,minutes = 30)  
            ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
            pub_date = ist_date_time[:10]
            publish_time = ist_date_time[11:]
        except:
            pass
        
   
        # skip null date
        if not pub_date:
            logger.info(f'Skipping due to date {source_link}\n')
            skipped_due_to_date += 1
            continue
         
        if pub_date != created_on:
            break 
            

        # journalist   
        journalist = c.scrap('"Person","name":"(.*?)"', page)
        if not journalist: journalist = 'NA'
            
        # source_content          
        source_content = c.scrap('"articleBody":"(.*?)"keywords"', page)
        source_content = re.sub('<.*?>','',source_content,flags=re.S) 
        source_content = c.strip_html(source_content)
        source_content = re.sub('&amp;','&',source_content,flags=re.S) 
        
         # current date and time 
        harvest_time = datetime.now().strftime("%H:%M:%S")

        # temp link
        temp_link = source_link

        # headline and content 
        headline = source_headline
        content = source_content

        # overall_tonality
        overall_tonality = ''

        # word count
        word_count = len((source_headline + ' ' + source_content).split())

        html_content = ''

        # image_urls
        image_urls = []

        # storing the above data in a dictionary
        clientdata ={
                        "client_master" : client_id, 
                        "articleid":client_id,
                        "medium":'Web' ,
                        "searchkeyword":[],
                        "entityname" : [] ,
                        "process_flage":"1",
                        "na_flage":"0",
                        "na_reason":"",
                        "qc_by":"",
                        "qc_on":"",
                        "location":"",
                        "spokeperson":"",
                        "quota":"",
                        "overall_topics":"",
                        "person":"",
                        "overall_entites":"",
                        "overall_tonality": overall_tonality,
                        "overall_wordcount":word_count,
                        "article_subjectivity":"",
                        "article_summary":"",
                        "pub_date":pub_date,
                        "publish_time":publish_time,
                        "harvest_time":harvest_time,
                        "temp_link":temp_link,
                        "publish_source": publish_source,
                        "programme":'null',
                        "feed_class":"News",
                        "publishing_platform":"",
                        "klout_score":"",
                        "journalist":journalist,
                        "headline":headline,
                        "content":content,
                        "source_headline":source_headline,
                        "source_content":source_content,
                        "language":language,
                        "presence":'null',
                        "clip_type":'null',
                        "prog_slot":'null',
                        "op_ed":'0',
                        "location_mention":'',
                        "source_link":source_link,
                        "author_contact":'',
                        "author_emailid":'',
                        "author_url":'',
                        "city":'',
                        "state":'',
                        "country":country,
                        "source":publish_source,
                        "foot_fall":'',
                        "created_on":created_on,
                        "active":'1',
                        'crawl_flag':2,
                        "images_path":images_path,
                        "html_content":html_content
                    } 

        cl_data.insert_one(clientdata)  
        no_of_data += 1


logger.info('Iteration complete\n')   

logger.info(f'Number of data: {no_of_data}\n')
logger.info(f'Duplicate data: {duplicate_data}\n')
logger.info(f'Unable to fetch rss url: {unable_to_fetch_rss_page}\n')
logger.info(f'Unable to fetch article url: {unable_to_fetch_url}\n')
logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')
# Out:
# https://brandequity.economictimes.indiatimes.com/rss/topstories
# https://brandequity.economictimes.indiatimes.com/news/marketing/reasons-for-setting-up-a-loyalty-program/81812396?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/advertising/amazon-and-flipkart-lead-ad-volume-share-of-online-shopping-category-tam-adex/81813554?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/digital/linkedin-working-on-clubhouse-like-audio-networking-feature/81813082?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/marketing/volkswagen-admits-marketing-prank-pulls-fake-release-on-name-change/81781825?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/recentstories
# https://brandequity.economictimes.indiatimes.com/news/digital/google-says-not-up-to-us-to-dictate-how-news-companies-spend-its-1-billion/81814988?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/marketing/ipl-2021-kansai-nerolac-continues-its-association-with-sunrisers-hyderabad/81815647?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/digital/no-immediate-relief-to-bytedance-on-plea-to-lift-bank-account-freeze/81814276?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/advertising/amazon-and-flipkart-lead-ad-volume-share-of-online-shopping-category-tam-adex/81813554?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/digital/linkedin-working-on-clubhouse-like-audio-networking-feature/81813082?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/marketing/reasons-for-setting-up-a-loyalty-program/81812396?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/marketing/volkswagen-admits-marketing-prank-pulls-fake-release-on-name-change/81781825?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/advertising
# https://brandequity.economictimes.indiatimes.com/news/advertising/81813554?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/advertising/81780680?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/marketing
# https://brandequity.economictimes.indiatimes.com/news/marketing/81781825?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/media
# https://brandequity.economictimes.indiatimes.com/news/media/81703607?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/digital
# https://brandequity.economictimes.indiatimes.com/news/digital/81814276?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/digital/81813082?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/news/digital/81774778?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/business-of-brands
# https://brandequity.economictimes.indiatimes.com/news/business-of-brands/81728013?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/the-people-report
# https://brandequity.economictimes.indiatimes.com/news/the-people-report/79607799?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/the-pitch-report
# https://brandequity.economictimes.indiatimes.com/news/the-pitch-report/81773752?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews
# https://brandequity.economictimes.indiatimes.com/news/advertising/the-amul-ad-aggressive-or-aggrieved/81752820?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/advertising
# https://brandequity.economictimes.indiatimes.com/news/advertising/the-amul-ad-aggressive-or-aggrieved/81752820?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/marketing
# https://brandequity.economictimes.indiatimes.com/news/marketing/money-matters-how-women-content-creators-are-shaking-up-the-bfsi-category/81770486?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/media
# https://brandequity.economictimes.indiatimes.com/news/media/media-and-entertainment-industry-expected-to-reach-inr-1-73-trillion-in-2021-ficci-ey-report-2021/81703607?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/digital
# https://brandequity.economictimes.indiatimes.com/news/digital/year-in-search-what-indians-did-online-in-2020-and-what-it-means-for-marketers/81676293?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/business-of-brands
# https://brandequity.economictimes.indiatimes.com/news/business-of-brands/major-fashion-brands-go-on-a-monogram-spree/81728013?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/the-people-report
# https://brandequity.economictimes.indiatimes.com/news/the-people-report/infectious-advertising-ropes-in-nitin-sharma-as-vp-business/81754461?utm_source=RSS&amp;utm_medium=ETRSS
# https://brandequity.economictimes.indiatimes.com/rss/topnews/the-pitch-report
# https://brandequity.economictimes.indiatimes.com/news/the-pitch-report/interactive-avenues-wins-the-digital-mandate-of-ralco-tyres/81755451?utm_source=RSS&amp;utm_medium=ETRSS
