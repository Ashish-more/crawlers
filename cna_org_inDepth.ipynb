# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *
    
# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'cna_org_inDepth'
c = Crawl()  # creating object

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_article_url = 0
publish_source = 'cna.org'
country = 'United States'
language = 'English'
images_path = []

# archive page
cat_page = c.download_page('https://www.cna.org/news/InDepth/')

for i in cat_page.split('ID:')[1:]:
    
    # source_link
    source_link = c.scrap('"(.*?)"',i)

    # handle duplicates
    source_link_query = {'source_link':source_link}
    dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
    if dic:
        duplicate_data += 1
        continue
        
    time.sleep(random.randint(1,3))
    
    # source_headline
    source_headline = c.scrap('title: "(.*?)"', i)
    print(source_headline)
    # skip if headline not found
    if not source_headline:
        logger.info(f'Skipping due to headline {source_link}\n')
        skipped_due_to_headline += 1
        continue

    # Date and time
    pub_date, publish_time = '', ''

    try:
        date_time_str = c.scrap('articleDate: "(.*?)"', i) + '00:00:00' # January 31, 2020
        date_time_obj = datetime.strptime(date_time_str, '%B %d, %Y%H:%M:%S')
        ist_date_time = date_time_obj + timedelta(hours = 5,minutes = 30)  # utc time to ist
        ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
        pub_date = ist_date_time[:10]
        publish_time = ist_date_time[11:]
    except:
        pass
        if not pub_date:
            pub_date = created_on
            publish_time = current_time

    # skip null date
    if not pub_date:
        logger.info(f'Skipping due to date {source_link}\n')
        skipped_due_to_date += 1
        continue

    # break if date is not today's date
#     if pub_date != created_on:
#         break    

    logger.info(f'Fetching {source_link}\n')
    
#     page = c.download_page(source_link)
#     if page.startswith('Unable to fetch'):
#         logger.info(page) # writes error message with error code
#         unable_to_fetch_article_url += 1
#         continue    
            
    # source_content          
    source_content = c.scrap('articleHTML:\s*"(.*?)}', i)
    source_content = c.strip_html(source_content)

    # skip if content not found
    if not source_content:
        logger.info(f'Skipping due to content {source_link}\n')
        skipped_due_to_content += 1
        continue

    # journalist
    journalist = c.scrap('author: "(.*?)"',i)
    if not journalist: journalist = 'NA'

    # current date and time 
    harvest_time = datetime.now().strftime("%H:%M:%S")

    # temp link
    temp_link = source_link

    # headline and content 
    headline = source_headline
    content = source_content

    # overall_tonality
    overall_tonality = ''

    # word count
    word_count = len((source_headline + ' ' + source_content).split())

    html_content = ''

    # image_urls
    image_urls = []
    
    # storing the above data in a dictionary
    clientdata ={
                    "client_master" : client_id, 
                    "articleid":client_id,
                    "medium":'Web' ,
                    "searchkeyword":[],
                    "entityname" : [] ,
                    "process_flage":"1",
                    "na_flage":"0",
                    "na_reason":"",
                    "qc_by":"",
                    "qc_on":"",
                    "location":"",
                    "spokeperson":"",
                    "quota":"",
                    "overall_topics":"",
                    "person":"",
                    "overall_entites":"",
                    "overall_tonality": overall_tonality,
                    "overall_wordcount":word_count,
                    "article_subjectivity":"",
                    "article_summary":"",
                    "pub_date":pub_date,
                    "publish_time":publish_time,
                    "harvest_time":harvest_time,
                    "temp_link":temp_link,
                    "publish_source": publish_source,
                    "programme":'null',
                    "feed_class":"News",
                    "publishing_platform":"",
                    "klout_score":"",
                    "journalist":journalist,
                    "headline":headline,
                    "content":content,
                    "source_headline":source_headline,
                    "source_content":source_content,
                    "language":language,
                    "presence":'null',
                    "clip_type":'null',
                    "prog_slot":'null',
                    "op_ed":'0',
                    "location_mention":'',
                    "source_link":source_link,
                    "author_contact":'',
                    "author_emailid":'',
                    "author_url":'',
                    "city":'',
                    "state":'',
                    "country":country,
                    "source":publish_source,
                    "foot_fall":'',
                    "created_on":created_on,
                    "active":'1',
                    'crawl_flag':2,
                    "images_path":images_path,
                    "html_content":html_content
                } 

    cl_data.insert_one(clientdata)  # get object id and insert data
    no_of_data += 1


logger.info('Iteration complete\n')   

logger.info(f'Number of data: {no_of_data}\n')
logger.info(f'Duplicate data: {duplicate_data}\n')
logger.info(f'Unable to article fetch url: {unable_to_fetch_article_url}\n')
logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')
# Out:
# Weighing the Costs of War and Peace in Afghanistan
# Can Kim Jong Un Really Denuclearize?
# Resolving the identity crisis in the military services
# Great Power Competition in the Red Sea? Yes, and…
# ISIS-Sinai&#39;s Violent Start to 2019
# Changing Policing Culture Through Community Members and Officers
# Exploring a Cyber Nirvana
# Rotational Crew Concept Catches on Among Close US Allies
# Do the SEALs Have a Culture Problem or an OPTEMPO Problem? The Answer Might be &quot;Yes&quot;
# The Demise of the INF Treaty and the Consequences for the Indo-Pacific
# Five Myths About Cryptocurrencies
# Prepare, Prepare, Prepare… For Hurricane Season
# Dorian: An Emergency Management Perspective
# What Do We Know About E-Cigarette Use Among U.S. Military Recruits? Spoiler Alert: Not Much.
# Integrating Civilian Protection into Security Assistance<br/><span style='font-size:0.8em'>Learning from Yemen</span>
# How the Bahamas Can Rebuild Quickly — Learning from Puerto Rico
# What do Greenland and Mauritius Have in Common, and Why Should Washington Care?
# Reducing the Navy&rsquo;s Risk of Suicides: CNA&rsquo;s Contribution to Better Approaches
# A U.S. View on Australia’s Role in the Indian Ocean<p><em>Canberra&rsquo;s diplomatic, legal, and military approaches to management of the Indian Ocean will be vital for US interests.</em></p>
# Wargaming is Just One Part of the Solution
# Many Contenders Eye the Pacific Island Countries
# Russia’s Not-So-Invisible Role in the Libyan Conflict
# Shifting the Scales in the Libyan Civil War: Russia’s Role in Intensifying the Conflict
# How to Create a Successful Space Service — Break the 20th Century Mold!
# China-Russia Energy Relations: Why the Power of Siberia Pipeline Matters to China
# Attack on U.S. Forces in Kenya: Strikes in Somalia have Failed to Halt al-Shabaab&rsquo;s Resurgence
# To Halt the 2019-nCoV Coronavirus, Think Globally, Coordinate Locally
# Three Questions, Ep. 01: Mallory Ladd
# Three Questions, Ep. 02: Kelly Diaz
# Hyping the Russia-China Pipeline
# Friend and Foe? Why Lebanon's New Government Matters for U.S. Defense Policy
# Three Questions, Ep. 03: Mary Lauer
# Three Questions, Ep. 04: Warren Sutton
# Reform Background Checks to Protect the Most Vulnerable
# Three Questions, Ep. 05: Daniel Powell
# The U.S. is Close to a Deal with the Taliban: What’s Next?
# Replacing the Draft 50 Years Ago Required Data and Dollars — It Still Does
# Maternity Leave: More Weeks for Mothers Can Mean More Weeks Worked
# Three Questions, Ep. 08: Nolan Noble
# Antarctica is the New Arctic: Security and Strategy in the Southern Ocean
# Symbolism and Capacity: Hospital Ships in the COVID-19 Response<p><em>It is valuable to consider how hospital ships can play a role in this response, but also to separate the symbolism of the deployments from the reality of the system-wide health crisis as it is unfolding.</em></p>
# Russia's Coronavirus Messaging and Disinformation
# Revisiting CNA's Pandemic Conference of 2006 — The View from 2020
# COVID-19's Maximum Pressure Campaign on North Korea
# Cooperation of Consequence: Lessons from the 2004 Tsunami Response in the Era of COVID-19
# Answers in the Air: A History of Connecting FAA Data to Emergency Management
# Modeling the Pandemic to Protect Prisoners and Staff
# Three Questions, Ep. 09: Matthew Grund
# Three Questions, Ep. 10: Justin Peachey
# Law Enforcement Innovates for the New Normal
# Thirteen COVID-19 Resources that Use Artificial Intelligence
# The Analyst's Most Underappreciated Tool: Writing
# The Blind Swing to Great Power Competition
# Does Kim Jong Un Have a Succession Plan?
# 5 Steps to Take Organizations to a New Normal that Works
# 14 More COVID-19 Resources that Use Artificial Intelligence
# The Challenge of Virtual Wargaming
# The Impact of COVID-19 on Military Recruiting
# The Four Elements of Successful Police Reform
# U.S. Forces are Weathering the COVID-19 Crisis — So Far
# Washington Takes a Stand in the South China Sea
# Global Issues Beckon Japan’s New Prime Minister
# 3 Steps Toward Transforming the Department of Defense
# The Evolution of Russian Election Disinformation
# New Delhi is Getting Serious About its Defense Partnership with Washington
# Why Are Special Operations Ever Conducted?
# When Should Agencies Start Reviewing Their Response to COVID-19? The Answer is Now
# China’s COVID-19 Propaganda Campaign
# Conducting After-Action Reviews on the COVID-19 Pandemic: Incorporating Oral Histories
# To Conduct an Effective Exercise During COVID-19, Go Virtual and Keep It Short
# 30 Years after Desert Storm, Lessons for Great Power Competition
# Overcoming the Logistical Hurdles of the COVID-19 Vaccine Supply Chain
# Digging Deeper on Great Power Competition in a New US Administration
# New Life for New START is a First Step for Nuclear Talks
# The Right Metrics and the Right Partner
# Wrong War, Right Weapons: Lessons for the Next Conflict
# From the Proceedings Archive: The Storm at Sea
# Law Enforcement-Community Engagement in the Era of COVID-19 and Calls for Social Justice
# Continuity During the COVID-19 Crisis
