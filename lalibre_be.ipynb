# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *
    
# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'lalibre_be'
c = Crawl()  # creating object

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_article_url = 0
unable_to_fetch_rss_url = 0
publish_source = 'lalibre.be'
country = 'Belgium'
language = 'French'
images_path = []

rss_pages = c.download_page('https://www.lalibre.be/rss/about')

for _ in rss_pages.split('class="linkRSS">')[1:]:
    
    rss_url = c.scrap('href="(.*?)"', _)
    if 'http' not in rss_url:
        rss_url = 'https://www.lalibre.be' + rss_url
    
    logger.info(f'Fetching Rss url {rss_url}\n')
    rss_page = c.download_page(rss_url)
    
    if rss_page.startswith('Unable to fetch'):
        logger.info(rss_page) # writes error message with error code
        unable_to_fetch_rss_url += 1
        continue

    for i in rss_page.split('<item>')[1:]:

        # source_link
        source_link = c.scrap("<link>(.*?)<", i)

        # handle duplicates
        source_link_query = {'source_link':source_link}
        dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
        if dic:
            duplicate_data += 1
            continue

        time.sleep(random.randint(1,3))
       
        # source_headline
        source_headline = c.scrap('<title>(.*?)</title>', i)
        
        # skip if headline not found
        if not source_headline:
            logger.info(f'Skipping due to headline {source_link}\n')
            skipped_due_to_headline += 1
            continue
         # Date and time
        pub_date, publish_time = '', ''

        try:
            date_time_str = c.scrap("<pubDate>\w+,(.*?)\+", i) # 07Apr2021081317
            date_time_str = re.sub(' |:','',date_time_str,re.S)
            date_time_obj = datetime.strptime(date_time_str, '%d%b%Y%H%M%S')
            # India is 3 hours and 30 minutes ahead of Belgium
            ist_date_time = date_time_obj + timedelta(hours = 3,minutes = 30)  # utc+8 to ist
            ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
            pub_date = ist_date_time[:10]
            publish_time = ist_date_time[11:]
        except:
            pass
    
        # skip null date
        if not pub_date:
            logger.info(f'Skipping due to date {source_link}\n')
            # print(f'Skipping due to date {source_link}\n')
            skipped_due_to_date += 1
            continue

        # break if date is not today's date
        if pub_date != created_on:
            break    

        logger.info(f'Fetching {source_link}\n')

        page = c.download_page(source_link)
        if page.startswith('Unable to fetch'):
                logger.info(page) # writes error message with error code
                unable_to_fetch_article_url += 1
                continue    

        # source_content          
        source_content = c.scrap('class="article-text">(.*?)<div\s*id="INREAD_LOADER">', page)
        if not source_content:
            source_content = c.scrap('"description":\s*"(.*?)"',page)        
        if not source_content:
            source_content = c.scrap('<meta\s*property="og:description".*?\((.*?)">',page)
        source_content = re.sub('Advertisement' , '', source_content, flags=re.S)
        source_content = c.strip_html(source_content)
       
        # skip if content not found
        if not source_content:
            logger.info(f'Skipping due to content {source_link}\n')
            skipped_due_to_content += 1
            continue

        # journalist
        journalist =  c.scrap('"author":"(.*?)"',page)
        if not journalist: journalist = 'NA'

        # current date and time 
        harvest_time = datetime.now().strftime("%H:%M:%S")

        # temp link
        temp_link = source_link

        # headline and content 
        headline = source_headline
        content = source_content

        # overall_tonality
        overall_tonality = ''

        # word count
        word_count = len((source_headline + ' ' + source_content).split())

        html_content = ''

        # image_urls
        image_urls = []

        # storing the above data in a dictionary
        clientdata ={
                        "client_master" : client_id, 
                        "articleid":client_id,
                        "medium":'Web' ,
                        "searchkeyword":[],
                        "entityname" : [] ,
                        "process_flage":"1",
                        "na_flage":"0",
                        "na_reason":"",
                        "qc_by":"",
                        "qc_on":"",
                        "location":"",
                        "spokeperson":"",
                        "quota":"",
                        "overall_topics":"",
                        "person":"",
                        "overall_entites":"",
                        "overall_tonality": overall_tonality,
                        "overall_wordcount":word_count,
                        "article_subjectivity":"",
                        "article_summary":"",
                        "pub_date":pub_date,
                        "publish_time":publish_time,
                        "harvest_time":harvest_time,
                        "temp_link":temp_link,
                        "publish_source": publish_source,
                        "programme":'null',
                        "feed_class":"News",
                        "publishing_platform":"",
                        "klout_score":"",
                        "journalist":journalist,
                        "headline":headline,
                        "content":content,
                        "source_headline":source_headline,
                        "source_content":source_content,
                        "language":language,
                        "presence":'null',
                        "clip_type":'null',
                        "prog_slot":'null',
                        "op_ed":'0',
                        "location_mention":'',
                        "source_link":source_link,
                        "author_contact":'',
                        "author_emailid":'',
                        "author_url":'',
                        "city":'',
                        "state":'',
                        "country":country,
                        "source":publish_source,
                        "foot_fall":'',
                        "created_on":created_on,
                        "active":'1',
                        'crawl_flag':2,
                        "images_path":images_path,
                        "html_content":html_content
                    } 

        cl_data.insert_one(clientdata)  
        no_of_data += 1


logger.info('Iteration complete\n')   

logger.info(f'Number of data: {no_of_data}\n')
logger.info(f'Duplicate data: {duplicate_data}\n')
logger.info(f'Unable to fetch rss url: {unable_to_fetch_rss_url}\n')
logger.info(f'Unable to fetch article url: {unable_to_fetch_article_url}\n')
logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')
# Out:
# https://www.lalibre.be/rss.xml
# https://www.lalibre.be/rss/section/belgique.xml
# https://www.lalibre.be/rss/section/belgique/politique-belge.xml
# https://www.lalibre.be/rss/section/belgique/enseignement.xml
# https://www.lalibre.be/rss/section/belgique/mobilite.xml
# https://www.lalibre.be/rss/section/belgique/judiciaire.xml
# https://www.lalibre.be/rss/section/belgique/societe.xml
# https://www.lalibre.be/rss/section/economie.xml
# https://www.lalibre.be/rss/section/economie/entreprises-startup.xml
# https://www.lalibre.be/rss/section/economie/decideurs-chroniqueurs.xml
# https://www.lalibre.be/rss/section/economie/placements.xml
# https://www.lalibre.be/rss/section/economie/mes-finances.xml
# https://www.lalibre.be/rss/section/economie/immo.xml
# https://www.lalibre.be/rss/section/economie/digital.xml
# https://www.lalibre.be/rss/section/economie/conjoncture.xml
# https://www.lalibre.be/rss/section/international.xml
# https://www.lalibre.be/rss/section/international/europe.xml
# https://www.lalibre.be/rss/section/international/amerique.xml
# https://www.lalibre.be/rss/section/international/asie.xml
# https://www.lalibre.be/rss/section/international/moyen-orient.xml
# https://www.lalibre.be/rss/section/international/afrique.xml
# https://www.lalibre.be/rss/section/international/oceanie.xml
# https://www.lalibre.be/rss/section/planete.xml
# https://www.lalibre.be/rss/section/planete/environnement.xml
# https://www.lalibre.be/rss/section/planete/sante.xml
# https://www.lalibre.be/rss/section/planete/sciences-espace.xml
# https://www.lalibre.be/rss/section/planete/inspire.xml
# https://www.lalibre.be/rss/section/sports.xml
# https://www.lalibre.be/rss/section/sports/football.xml
# https://www.lalibre.be/rss/section/sports/tennis.xml
# https://www.lalibre.be/rss/section/sports/golf.xml
# https://www.lalibre.be/rss/section/sports/moteurs.xml
# https://www.lalibre.be/rss/section/sports/cyclisme.xml
# https://www.lalibre.be/rss/section/sports/hockey.xml
# https://www.lalibre.be/rss/section/sports/omnisports.xml
# https://www.lalibre.be/rss/section/culture.xml
# https://www.lalibre.be/rss/section/culture/cinema.xml
# https://www.lalibre.be/rss/section/culture/musique.xml
# https://www.lalibre.be/rss/section/culture/arts.xml
# https://www.lalibre.be/rss/section/culture/medias-tele.xml
# https://www.lalibre.be/rss/section/culture/livres-bd.xml
# https://www.lalibre.be/rss/section/culture/scenes.xml
# https://www.lalibre.be/rss/section/culture/politique.xml
# https://www.lalibre.be/rss/section/lifestyle.xml
# https://www.lalibre.be/rss/section/lifestyle/magazine.xml
# https://www.lalibre.be/rss/section/lifestyle/deco-design.xml
# https://www.lalibre.be/rss/section/lifestyle/love-sex.xml
# https://www.lalibre.be/rss/section/lifestyle/food.xml
# https://www.lalibre.be/rss/section/lifestyle/mode.xml
# https://www.lalibre.be/rss/section/lifestyle/people.xml
# https://www.lalibre.be/rss/section/lifestyle/voyages.xml
# https://www.lalibre.be/rss/section/debats.xml
# https://www.lalibre.be/rss/section/debats/edito.xml
# https://www.lalibre.be/rss/section/debats/opinions.xml
# https://www.lalibre.be/rss/section/debats/ripostes.xml
# https://www.lalibre.be/rss/section/debats/diplomatie.xml
# https://www.lalibre.be/rss/section/debats/chronique-redaction.xml
# https://www.lalibre.be/rss/section/regions.xml
# https://www.lalibre.be/rss/section/regions/bruxelles.xml
# https://www.lalibre.be/rss/section/regions/brabant.xml
# https://www.lalibre.be/rss/section/regions/flandre.xml
# https://www.lalibre.be/rss/section/regions/liege.xml
# https://www.lalibre.be/rss/section/regions/hainaut.xml
# https://www.lalibre.be/rss/section/regions/namur.xml
# https://www.lalibre.be/rss/section/lifestyle/quiz-concours.xml
# https://www.lalibre.be/rss/section/grands-formats.xml
# https://www.lalibre.be/rss/dossiers.xml
# https://www.lalibre.be/rss/dossier/5e304b4cf20d5a6521f0a721.xml
# https://www.lalibre.be/rss/dossier/606569977b50a6051773270e.xml
# https://www.lalibre.be/rss/dossier/602ccb2e9978e2610aac7990.xml
# https://www.lalibre.be/rss/dossier/5769413b35708dcfedb40eaf.xml
# https://www.lalibre.be/rss/dossier/5ea7dc079978e21833f48662.xml
# https://www.lalibre.be/rss/dossier/5f61d3cad8ad58621913f464.xml
# https://www.lalibre.be/rss/dossier/5f61d5499978e2322f0eca16.xml
# https://www.lalibre.be/rss/dossier/5e1353879978e272f9a70d19.xml
# https://www.lalibre.be/rss/dossier/5319cd913570f1ef1aab1c90.xml
# https://www.lalibre.be/rss/dossier/52693fce35703b1265358b65.xml
# https://www.lalibre.be/rss/dossier/602547937b50a62acfcd0acb.xml
# https://www.lalibre.be/rss/dossier/5e4160e2f20d5a72108e7b3a.xml
# https://www.lalibre.be/rss/infos.xml
# https://www.lalibre.be/rss/infos/afp.xml
# https://www.lalibre.be/rss/infos/belga.xml
