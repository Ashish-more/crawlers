# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *
    
# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'rt_com'
c = Crawl()  # creating object

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_article_url = 0
publish_source = 'rt.com'
country = 'Russia'
language = 'English'
images_path = []

# archive page
rss_page = c.download_page('https://www.rt.com/rss-feed/')

for i in rss_page.split('<item>')[1:]:
    
    # source_link
    source_link = c.scrap("<link>(.*?)</link>", i)
    source_link = source_link.replace("<![CDATA[","").replace("]]>","")

    # handle duplicates
    source_link_query = {'source_link':source_link}
    dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
    if dic:
        duplicate_data += 1
        continue
        
    time.sleep(random.randint(1,3))
    
    # source_headline
    source_headline = c.scrap("<title>(.*?)<", i)

    # skip if headline not found
    if not source_headline:
        logger.info(f'Skipping due to headline {source_link}\n')
        skipped_due_to_headline += 1
        continue

    # Date and time
    pub_date, publish_time = '', ''

    try:
        date_time_str = c.scrap("<pubDate>\w+,(.*?)\+", i) 
        date_time_str = re.sub(' |:','',date_time_str,re.S)
        date_time_obj = datetime.strptime(date_time_str, '%d%b%Y%H%M%S')
        ist_date_time = date_time_obj + timedelta(hours = 5,minutes = 30)  # utc time to ist
        ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
        pub_date = ist_date_time[:10]
        publish_time = ist_date_time[11:]
    except:
        pass


    # skip null date
    if not pub_date:
        logger.info(f'Skipping due to date {source_link}\n')
        skipped_due_to_date += 1
        continue

    # break if date is not today's date
#     if pub_date != created_on:
#         break    

    logger.info(f'Fetching {source_link}\n')
    
    page = c.download_page(source_link)
    if page.startswith('Unable to fetch'):
        logger.info(page) # writes error message with error code
        unable_to_fetch_article_url += 1
        continue    
            
    # source_content          
    source_content = c.scrap('<content:encoded>(.*?)</content:encoded>', i)
    source_content = re.sub(']]>','',source_content,re.S)
    source_content = c.strip_html(source_content)

    # skip if content not found
    if not source_content:
        logger.info(f'Skipping due to content {source_link}\n')
        skipped_due_to_content += 1
        continue

    # journalist
    journalist = c.scrap('name="article:author" content="(.*?)"',page)
    if not journalist: journalist = 'NA'

    # current date and time 
    harvest_time = datetime.now().strftime("%H:%M:%S")

    # temp link
    temp_link = source_link

    # headline and content 
    headline = source_headline
    content = source_content

    # overall_tonality
    overall_tonality = ''

    # word count
    word_count = len((source_headline + ' ' + source_content).split())

    html_content = ''

    # image_urls
    image_urls = []
    
    # storing the above data in a dictionary
    clientdata ={
                    "client_master" : client_id, 
                    "articleid":client_id,
                    "medium":'Web' ,
                    "searchkeyword":[],
                    "entityname" : [] ,
                    "process_flage":"1",
                    "na_flage":"0",
                    "na_reason":"",
                    "qc_by":"",
                    "qc_on":"",
                    "location":"",
                    "spokeperson":"",
                    "quota":"",
                    "overall_topics":"",
                    "person":"",
                    "overall_entites":"",
                    "overall_tonality": overall_tonality,
                    "overall_wordcount":word_count,
                    "article_subjectivity":"",
                    "article_summary":"",
                    "pub_date":pub_date,
                    "publish_time":publish_time,
                    "harvest_time":harvest_time,
                    "temp_link":temp_link,
                    "publish_source": publish_source,
                    "programme":'null',
                    "feed_class":"News",
                    "publishing_platform":"",
                    "klout_score":"",
                    "journalist":journalist,
                    "headline":headline,
                    "content":content,
                    "source_headline":source_headline,
                    "source_content":source_content,
                    "language":language,
                    "presence":'null',
                    "clip_type":'null',
                    "prog_slot":'null',
                    "op_ed":'0',
                    "location_mention":'',
                    "source_link":source_link,
                    "author_contact":'',
                    "author_emailid":'',
                    "author_url":'',
                    "city":'',
                    "state":'',
                    "country":country,
                    "source":publish_source,
                    "foot_fall":'',
                    "created_on":created_on,
                    "active":'1',
                    'crawl_flag':2,
                    "images_path":images_path,
                    "html_content":html_content
                } 

    cl_data.insert_one(clientdata)  # get object id and insert data
    no_of_data += 1


logger.info('Iteration complete\n')   

logger.info(f'Number of data: {no_of_data}\n')
logger.info(f'Duplicate data: {duplicate_data}\n')
logger.info(f'Unable to article fetch url: {unable_to_fetch_article_url}\n')
logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')
# Out:
# https://www.rt.com/usa/520422-nude-photos-lawsuit-katie-hill/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Judge rules nude photos of ex-congresswoman Katie Hill, who resigned after sex scandal, are â€˜matter of public concernâ€™
# https://www.rt.com/usa/520420-youtube-desantis-lockdown-video/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# YouTube REMOVES roundtable video featuring Florida Gov. DeSantis &amp; anti-lockdown health experts, citing â€˜terms of serviceâ€™
# https://www.rt.com/news/520419-state-department-iran-sanctions/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# State Dept says US prepared to lift Iran sanctions, but warns of â€˜long road aheadâ€™ amid indirect talks to revive nuclear pact
# https://www.rt.com/usa/520418-florida-police-identity-shootings/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Meets the definition of a crime victimâ€™: Florida court rules police can hide officersâ€™ identity after on-duty shootings
# https://www.rt.com/usa/520413-twitch-deplatform-offline-offenders/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Megalomania or protecting users? New Twitch policy prepares to deplatform for OFF-PLATFORM activity
# https://www.rt.com/news/520417-oil-refinery-fre-mexico/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# EXPLOSION and fire rock Mexican oil refinery in Veracruz state (VIDEO)
# https://www.rt.com/usa/520416-texas-migrants-child-abuse/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Health &amp; safety nightmareâ€™: Texas governor demands closure of migrant child facility after claims of SEXUAL ABUSE
# https://www.rt.com/news/520415-spain-astrazeneca-blood-clot/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Spain restricting AstraZeneca Covid-19 vaccine to over-60s after EMA blood-clot warning
# https://www.rt.com/usa/520409-raimondo-trump-tariffs-jobs-biden/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Bidenâ€™s Commerce secretary says Trump tariffs â€˜helped save American jobsâ€™ &amp; indicates sheâ€™ll keep them
# https://www.rt.com/news/520414-syria-israel-attack-damascus/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# 4 Syrian soldiers injured in &#039;Israeli aggression&#039; over Damascus, Syrian state media report
# https://www.rt.com/usa/520412-idaho-bans-vaccine-passports/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Idaho bans â€˜vaccine passports,â€™ becoming THIRD US state to do so
# https://www.rt.com/sport/520410-psg-bayern-ucl-mbappe/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Double act Mbappe and Neymar fire pair of goals and assists in PSG-Bayern 3-2 thriller
# https://www.rt.com/uk/520406-belfast-bus-torched-protest-northernireland/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# WATCH: Bus TORCHED by petrol bomb as it drives along Belfast road amid ongoing Northern Ireland protests
# https://www.rt.com/sport/520411-fans-praise-mason-mount-chelsea-porto/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Mount makes history as dark horses Chelsea seize Champions League initiative vs Porto
# https://www.rt.com/news/520408-biden-north-korea-diplomacy/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Biden administration ready to consider â€˜some form of diplomacyâ€™ with North Korea â€“ White House
# https://www.rt.com/usa/520401-dimon-income-inequality-belated-pitchforks/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# JPMorgan Chase predicts economic boom and pats itself on the back over steps during pandemic
# https://www.rt.com/usa/520405-teachers-union-anti-semitism/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Jewish journalist accuses Jewish union leader of anti-Semitism in argument about school teaching
# https://www.rt.com/news/520402-us-resumes-palestine-aid/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# US announces $235mn aid package for Palestinians, backs 2-state solution to conflict with Israel
# https://www.rt.com/sport/520399-mcgregor-mocks-khabib-ufc-bus-incident/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜The Dagi on the bus goes poo, poo, pooâ€™: McGregor insults Khabib on 3rd anniversary of Russian starâ€™s UFC title win
# https://www.rt.com/sport/520396-shaq-engagement-ring-viral/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Big guy, big heart: NBA icon Shaq steps in to buy random stranger&#039;s engagement ring (VIDEO)
# https://www.rt.com/news/520400-us-iraq-combat-troops/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# US agrees to withdraw &#039;remaining combat troops&#039; from Iraq â€“ reports
# https://www.rt.com/sport/520398-yulia-efimova-loss-evgenia-chikunova/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Good replacement for when I retire!â€™ Russian swimming champ Efimova on her shock defeat to 16yo star
# https://www.rt.com/news/520393-jordan-king-sedition-ended-hamzah/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Jordan&#039;s King Abdullah says &#039;sedition is buried&#039; following &#039;painful&#039; rift with half-brother arrested after criticizing govt
# https://www.rt.com/usa/520394-biden-miracle-immigrant-deported/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Deportation for former &#039;permanent resident&#039; with drugs conviction who hoped for &#039;miracle&#039; under Biden
# https://www.rt.com/sport/520390-woods-crash-masters-golf/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Tiger Woods was driving ALMOST DOUBLE SPEED LIMIT before horror crash, police reveal
# https://www.rt.com/news/520391-czech-tank-gun-amnesty/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Nationwide weapon amnesty prompts citizen to turn TANK and ARTILLERY GUN over to the authorities (PHOTOS)
# https://www.rt.com/news/520359-hubble-spots-double-quasars-merging/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Hubble Telescope finds 2 â€˜needlesâ€™ in separate galactic haystacks with double-quasar discovery
# https://www.rt.com/sport/520386-ireland-euro2020-uefa-football/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Dublin Euro 2020 games thrown into doubt after Irish FA refuses to commit on crowd numbers
# https://www.rt.com/usa/520388-patient-notes-racial-bias-study/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Doctors more likely to doubt black patients than white, study finds after reviewing practitionersâ€™ records
# https://www.rt.com/sport/520373-emma-jones-perverts-instagram/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Ah, internetâ€™: Pin-up football presenter Jones shares bizarre online requests including fan asking to â€˜sniff her sweaty toesâ€™
# https://www.rt.com/usa/520309-yelp-asian-businesses-race-baiting/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# As Yelp continues to atomize working class communities, Asian business owners get the BLM treatment
# https://www.rt.com/uk/520385-uk-alternative-astrazeneca-covid-vaccine-young/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# UK to offer under-30s alternative Covid-19 vaccine amid evidence linking AstraZeneca jab to blood clots
# https://www.rt.com/sport/520383-tennis-player-loss-umpire-mistake/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Outrageousâ€™: Australian tennis player loses match after umpire confuses the score
# https://www.rt.com/news/520384-thailand-covid-field-hospitals-uk-variant/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Thai PM orders authorities to prepare Covid-19 field hospitals after UK variant spreads to country
# https://www.rt.com/news/520382-europe-leyen-chair-brussels-erdogan/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Sofagate: Von der Leyen â€˜surprisedâ€™ after embarrassingly left without a chair at EU summit with Turkish president
# https://www.rt.com/uk/520358-national-trust-empire-poetry/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Woke history or telling it as it is? National Trust under fire for encouraging children to write poems critical of British Empire
# https://www.rt.com/sport/520380-gary-lineker-tweet-thank-young-people-covid/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# All kicking off: Lineker triggers Twitter turmoil as he says young people should be â€˜thanked for their diligenceâ€™ during pandemic
# https://www.rt.com/news/520360-turkey-erdogan-istanbul-canal/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Turkey will push Istanbul canal plan forward â€˜whether you like it or notâ€™, Erdogan says, promises to â€˜lay groundworkâ€™ this summer
# https://www.rt.com/news/520379-wef-smart-mask-future/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜They want you in masks foreverâ€™: World Economic Forumâ€™s smart â€˜mask of the futureâ€™ tweet spooks Twitter users
# https://www.rt.com/russia/520378-germany-ukraine-nato-unlikely/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# NATO has an open door policy, but Ukraine unlikely to walk through it any time soon, German officials say amid Donbass escalations
# https://www.rt.com/business/520368-air-passenger-traffic-fall/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# No signs of demand recovery: Global air passenger traffic continues to fall, IATA says
# https://www.rt.com/news/520374-turkey-aerobatic-jet-crash/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Pilot killed as jet from Turkish Air Force aerobatic team crashes during training
# https://www.rt.com/news/520371-member-who-covid-19-study/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Inconclusive and terribly complex: Member of WHO Covid-19 origin study talks report and politics with RT
# https://www.rt.com/news/520372-iran-president-indirect-nuclear-talks/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Iranâ€™s Rouhani hails â€˜new chapterâ€™ after Washington and Tehran kick off indirect nuclear deal talks
# https://www.rt.com/news/520375-ema-bloodclot-link-astrazeneca-covid/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# EU drugs regulator finds possible link between AstraZenecaâ€™s Covid vaccine and â€˜very rare cases of unusual blood clotsâ€™
# https://www.rt.com/sport/520361-tyler-east-dead-mma-shooting/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Troubled former MMA fighter Tyler &#039;The Beast&#039; East killed in New Mexico shooting
# https://www.rt.com/russia/520370-recalled-ambassador-back-washington/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Russia unlikely to send recalled ambassador back to Washington without clear sign US ready for bilateral relations, Moscow insists
# https://www.rt.com/russia/520365-eastern-military-bloc-nato-compete/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Russia &amp; China wonâ€™t create Eastern military bloc to rival NATO because exclusive clubs are â€˜counter-productive,â€™ says FM Lavrov
# https://www.rt.com/news/520362-south-korea-suspends-astrazeneca-covid-vaccine/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# South Korea suspends use of AstraZeneca Covid-19 vaccine in people under 60 ahead of EU blood clot review results
# https://www.rt.com/news/520367-germany-lockdown-merkel-favor/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Merkel backs shock lockdown to stem rising Covid cases across Germany
# https://www.rt.com/sport/520357-deshaun-watson-assault-nfl/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# NFL star Deshaun Watson claims sex assault accuser demanded $100K hush money as two women speak out publicly
# https://www.rt.com/news/520354-covid-neurological-psychiatric-problems/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# 1 in 3 Covid-19 survivors develop neurological or psychiatric problems within 6 months â€“ study
# https://www.rt.com/news/520363-taiwan-china-usa-aircraft-warship/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Taipei reports 15 Chinese planes buzzing its airspace as US warship enters Taiwan Strait
# https://www.rt.com/news/520349-fukushima-radioactive-water-disposal/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Dumping of Fukushima radioactive water into ocean â€˜unavoidableâ€™, Japanese PM says, as countryâ€™s fisheries reject plan
# https://www.rt.com/sport/520348-mayweather-white-ufc-rizin/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜WTF is going on here?â€™: UFC boss White and boxing icon Mayweather spark speculation frenzy after sharing photo of meeting
# https://www.rt.com/russia/520356-zoom-licensing-ban-sale/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Cameras off! Zoom bans sales to Russian government &amp; state-owned companies, as analysts claim fear of US sanctions is behind move
# https://www.rt.com/news/520336-moderna-germany-vaccine-supply/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Moderna insists Covid vaccine deliveries on track after report claims it wonâ€™t be able to deliver up to 878,000 doses to Germany
# https://www.rt.com/sport/520355-china-responds-us-boycott-2022-winter-olympics/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# China warns of â€˜robust responseâ€™ to any Olympics boycott after US stirs talk of skipping 2022 Beijing Games
# https://www.rt.com/business/520351-digital-yuan-us-dollar/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Could rapid development of Chinaâ€™s digital currency threaten US&#039; global dominance? RTâ€™s Boom Bust digs in
# https://www.rt.com/business/520337-beijing-world-billionaire-capital/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Beijing edges out NYC as home to most billionaires â€“ Forbes 2021 list
# https://www.rt.com/sport/520353-nba-team-bitcoin-payment/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜They can get paid in bitcoin as much as they wantâ€™: Owner of NBAâ€™s Sacramento Kings offers to pay players in cryptocurrency
# https://www.rt.com/news/520352-serum-institute-covid-vaccine-financial-support/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Worldâ€™s largest vaccine manufacturer requests financial help after India imposes Covid jab export restrictions
# https://www.rt.com/russia/520346-grechin-ukrainian-dubai-arrest/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Ukrainian detained in Dubai over raunchy naked balcony photoshoot claimed to be US Democratic Party adviser, local media reports
# https://www.rt.com/news/520350-iran-nuclear-uranium-deal-threat/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Iranâ€™s Atomic Energy Organization says 55 kilos of 20%-enriched uranium produced since January amid nuclear deal talks
# https://www.rt.com/sport/520332-haaland-autograph-city-dortmund/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Childishâ€™ Romanian official blasted after heâ€™s spotted getting Haalandâ€™s autograph following Champions League tie
# https://www.rt.com/sport/520345-umar-nurmagomedov-surgery-recovery/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜6 months of recovery aheadâ€™: Umar Nurmagomedov reveals UFC setback after ligament surgery
# https://www.rt.com/news/520347-myanmar-military-opens-fire-violent-clashes/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# 7 reported killed as Myanmar military opens fire in latest conflict between anti-coup protesters and security forces
# https://www.rt.com/news/520344-eurostate-covid-life-expectancy/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# The missing years: Covid shaves years off life expectancy rates across EU
# https://www.rt.com/business/520324-russia-metals-profits-budget/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Russia may allocate extra metal profits to budget to stabilize prices â€“ reports
# https://www.rt.com/russia/520334-eu-great-eurasian-partnership/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# European Union welcome in new Russian-backed â€˜Great Eurasian Partnershipâ€™, Moscow saysâ€¦ if Brussels sees value in turning to East
# https://www.rt.com/news/520327-watch-business-owners-clash-with-police-rome/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# WATCH business owners clash with police as anti-lockdown protest turns violent in Rome
# https://www.rt.com/news/520323-rescuers-free-trapped-monk-thailand/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Rescuers extract Buddhist monk from flooded cave after harrowing 4-day ordeal (PHOTOS)
# https://www.rt.com/uk/520325-tech-regulator-conduct-facebook-google/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# UK seeks to curb Big Tech â€˜dominanceâ€™ with launch of new regulator
# https://www.rt.com/sport/520335-bryson-dechambeau-crazy-practice-swings/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜A miracle if his back survivesâ€™: Golf hulk DeChambeau baffles fans with crazy speed-swing tee shots ahead of US Masters (VIDEO)
# https://www.rt.com/russia/520291-war-vet-all-terrain-vehicle/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Russian Afghanistan War vet fulfills childhood dream by building all-terrain vehicle using parts from 12 different cars (VIDEO)
# https://www.rt.com/uk/520333-extinction-rebellion-bank-barclays/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Extinction Rebellion activists arrested outside Barclays London HQ after breaking windows to protest bankâ€™s fossil fuel financing
# https://www.rt.com/russia/520331-foreign-agents-election-participation/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Foreign agentsâ€™ who take cash from overseas will be allowed run in upcoming Russian elections, as long as they donâ€™t hide status
# https://www.rt.com/business/520322-coinbase-record-revenue-nasdaq-listing/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Coinbase reports record $1.8 BILLION revenue for Q1 ahead of its Nasdaq listing
# https://www.rt.com/uk/520330-britain-covid19-moderna-vaccine/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# UK starts rollout of Moderna Covid-19 jab ahead of schedule, with 5,000 doses distributed to vaccination centres in Wales
# https://www.rt.com/news/520329-iran-cargo-ship-attack/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Iran confirms attack on its cargo ship anchored off Yemen, vessel sustained â€˜minor damageâ€™
# https://www.rt.com/business/520321-russia-oil-production-forecast/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Russia slashes 2021-2022 oil production forecasts
# https://www.rt.com/usa/520316-united-arlines-diversity-pilots-woke/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Taking wokeism to new heights? United Airlines pledges 50% of pilot trainees will be women &amp; minorities
# https://www.rt.com/news/520317-taiwan-military-exercise-china/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Taiwan to hold drills simulating â€˜enemy invasionâ€™ amid rising tensions with Beijing
# https://www.rt.com/news/520315-australia-3-million-vaccines-eu/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Australian PM Morrison calls on EU to release 3.1mn vaccine doses after Brussels denies blocking shipments
# https://www.rt.com/usa/520314-fairfax-george-floyd-comparison/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Virginia lieutenant governor sees backlash for comparing calls to resign over sexual assault scandal to â€˜being treated like Floydâ€™
# https://www.rt.com/usa/520313-nasa-migrant-children-assistance/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# NASA staff now asked to help care for migrant children amid surge at US-Mexico border
# https://www.rt.com/usa/520311-bezos-amazon-tax-hike/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Jeff Bezos says Amazon backs Bidenâ€™s corporate tax hike, gets roasted for â€˜exploiting loopholesâ€™ to pay less
# https://www.rt.com/usa/520310-cotton-prisons-crime-backlash/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# &#039;We have a major under-incarceration problem&#039;: Sen. Tom Cottonâ€™s hot take on rising crime fuels online outrage
# https://www.rt.com/usa/520308-caitlyn-jenner-california-governor/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Republican-linked transgender for California? Caitlyn Jenner reportedly considers running for governor
# https://www.rt.com/sport/520306-us-olympic-boycott-china/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# US considers BOYCOTT of 2022 Beijing Olympics, may convince allies to skip winter games â€“ State Department
# https://www.rt.com/sport/520299-alexander-arnold-liverpool-madrid/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Used him as a training coneâ€™: Liverpoolâ€™s Alexander-Arnold roasted for Champions League nightmare at Real Madrid
# https://www.rt.com/russia/520304-dubai-naked-photoshoot-deportation/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Group of models from scandalous NAKED high-rise photoshoot in Dubai will avoid prison &amp; be deported from UAE, authorities say
# https://www.rt.com/news/520303-iran-ship-redsea-israel-attack/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Iranian â€˜spy shipâ€™ damaged in â€˜attackâ€™ along major Red Sea shipping route â€“ reports
# https://www.rt.com/usa/520305-arkansas-transgender-bill/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Arkansas becomes first state to ban surgery, hormones and puberty blockers for transgender youths
# https://www.rt.com/sport/520302-video-bellingham-goal-dortmund-man-city/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Genuinely appallingâ€™: Fans FURIOUS after referee rules out â€˜perfectly good goalâ€™ for Dortmund against Man City (VIDEO)
# https://www.rt.com/uk/520300-uk-hospitality-court-appeal-covid/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# UK govt loses bid to delay court case brought by hospitality sector over prolonged Covid closure of pubs &amp; restaurants
# https://www.rt.com/usa/520295-texas-bans-vaccine-passports-florida/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Texas becomes 2nd US state to BAN vaccine passports as issue splits country politically
# https://www.rt.com/sport/520296-mlb-atlanta-colorado-baseball-backlash/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# MLB confirms All-Star game will head to Colorado after ditching Georgia â€“ gets accused of woke misstep
# https://www.rt.com/usa/520298-cnbc-florida-voting/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# â€˜Activism, not journalismâ€™: CNBC called out for article pressuring corporations into taking position on Florida voting laws
# https://www.rt.com/sport/520288-bonnar-mask-covid-ufc/?utm_source=rss&utm_medium=rss&utm_campaign=RSS
# Ex-UFC star Bonnar rants about â€˜sheepâ€™, refers to the suffering of Jesus Christ after being kicked out of gym over mask issue
