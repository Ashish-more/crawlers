# %%
import json
import os 
import requests
import time
from datetime import datetime,timedelta
from datetime import date
import re
import sys
import urllib, urllib.request, urllib.parse
import random
from scrawl import *
    
# Date and time
start_time = time.time()
current_time = datetime.now().strftime("%H-%M-%S")
created_on = date.today().strftime("%Y-%m-%d")

# client_id = sys.argv[1]
client_id = '5f69d22ef472d6646f577fa6'  # Europe
site = 'mod_go_jp_wpaper_publication'
c = Crawl()  # creating object

# create directories to store logs.
log_path = c.create_directories(project_path, client_id, site)

# create image directories
image_directory = c.create_image_directories(project_path)

# creating pdf directories
pdf_directory = c.create_pdf_directories(project_path, site)

# logger
logger = log_func(log_path, created_on, current_time)
logger.info("Process Started ...\n")

# initialize variables
skipped_due_to_headline = 0
skipped_due_to_content = 0
skipped_due_to_date = 0
missing_overall_tonality = 0
no_of_data = 0
duplicate_data = 0  
unable_to_fetch_url = 0
unable_to_download_image = 0
unable_to_download_pdf = 0
publish_source = 'mod.go.jp'
country = 'United States'
language = 'English'
images_path = []

# archive page
for year in range(20,30):
    cat = f"https://www.mod.go.jp/e/publ/w_paper/wp20{year}/pdf/index.html"
    cat = c.download_page(cat)
    if '<title>404 Not Found' in cat:
        break
    cat = c.download_page(cat)
    for i in cat.split('<li>S')[1:]:

        # source_link
        source_link = c.scrap('href="(.*?)"', i)

        if 'http' not in source_link:
            source_link = f'https://www.mod.go.jp/e/publ/w_paper/wp20{year}/pdf/' + source_link

        # handle duplicates
        source_link_query = {'source_link':source_link}
        dic = cl_data.find_one(source_link_query,{'source_link': 1}) 
        if dic:
            duplicate_data += 1
            continue

        time.sleep(random.randint(1,6))

#         page = c.download_page(source_link)
#         if page.startswith('Unable to fetch'):
#             logger.info(page) # writes error message with error code
#             unable_to_fetch_url += 1
#             continue 

        # source_headline
        source_headline = c.scrap('href=".*?>(.*?)<', i)

        # skip if headline not found
        if not source_headline:
            logger.info(f'Skipping due to headline {source_link}\n')
            skipped_due_to_headline += 1
            continue

        # Date and time
        pub_date, publish_time = '', ''

        try:
            date_time_str = created_on + '000000'      
            date_time_obj = datetime.strptime(date_time_str, '%Y-%m-%d%H%M%S') #2020-12-08T12:00:00
            ist_date_time = date_time_obj + timedelta(hours = 0,minutes = 0)  # utc time to ist
            ist_date_time = ist_date_time.strftime('%Y-%m-%d %H:%M:%S')
            pub_date = ist_date_time[:10]
            publish_time = ist_date_time[11:]
        except:
            pass

        # skip null date
        if not pub_date:
            logger.info(f'Skipping due to date {source_link}\n')
            skipped_due_to_date += 1
            continue

        # break if date is not today's date
    #     if pub_date != created_on:
    #         break    

        logger.info(f'Fetching {source_link}\n')

        # source_content          
        source_content = source_headline
        source_content = c.strip_html(source_content)

        # skip if content not found
        if not source_content:
            logger.info(f'Skipping due to content {source_link}\n')
            skipped_due_to_content += 1
            continue

        # journalist
        journalist = ''
        if not journalist: journalist = 'NA'

        # current date and time 
        harvest_time = datetime.now().strftime("%H:%M:%S")

        # temp link
        temp_link = source_link

        # headline and content 
        headline = source_headline
        content = source_content

        # overall_tonality
        overall_tonality = ''

        # word count
        word_count = len((source_headline + ' ' + source_content).split())

        html_content = ''

        # image_urls
        image_urls = []

        pdf_path, pdf_name = '', ''

        pdf_url = c.scrap('href="(.*?)"', i)
        pdf_url = f'https://www.mod.go.jp/e/publ/w_paper/wp20{year}/pdf/' + pdf_url

        if pdf_url:         
            # pdf_name
            pdf_name = c.scrap('.*/(.*)', pdf_url)

            # pdf_path
            pdf_path = f'{pdf_directory}/{pdf_name}'        

            # download pdf
            pdf = c.download_pdf(pdf_url, pdf_path)
            if pdf.startswith('Unable to fetch'):
                logger.info(pdf) # writes error message with error code
                unable_to_download_pdf += 1
                continue   


        # storing the above data in a dictionary
        clientdata ={
                        "client_master" : client_id, 
                        "articleid":client_id,
                        "medium":'Web' ,
                        "searchkeyword":[],
                        "entityname" : [] ,
                        "process_flage":"1",
                        "na_flage":"0",
                        "na_reason":"",
                        "qc_by":"",
                        "qc_on":"",
                        "location":"",
                        "spokeperson":"",
                        "quota":"",
                        "overall_topics":"",
                        "person":"",
                        "overall_entites":"",
                        "overall_tonality": overall_tonality,
                        "overall_wordcount":word_count,
                        "article_subjectivity":"",
                        "article_summary":"",
                        "pub_date":pub_date,
                        "publish_time":publish_time,
                        "harvest_time":harvest_time,
                        "temp_link":temp_link,
                        "publish_source": publish_source,
                        "programme":'null',
                        "feed_class":"News",
                        "publishing_platform":"",
                        "klout_score":"",
                        "journalist":journalist,
                        "headline":headline,
                        "content":content,
                        "source_headline":source_headline,
                        "source_content":source_content,
                        "language":language,
                        "presence":'null',
                        "clip_type":'null',
                        "prog_slot":'null',
                        "op_ed":'0',
                        "location_mention":'',
                        "source_link":source_link,
                        "author_contact":'',
                        "author_emailid":'',
                        "author_url":'',
                        "city":'',
                        "state":'',
                        "country":country,
                        "source":publish_source,
                        "foot_fall":'',
                        "created_on":created_on,
                        "active":'1',
                        'crawl_flag':2,
                        "images_path":images_path,
                        "html_content":html_content,
                        "pdf_url": pdf_url,
                        "pdf_name": pdf_name,
                        "pdf_path":pdf_path
                    } 

        cl_data.insert_one(clientdata)  # get object id and insert data
        no_of_data += 1


    logger.info('Iteration complete\n')   

    logger.info(f'Number of data: {no_of_data}\n')
    logger.info(f'Duplicate data: {duplicate_data}\n')
    logger.info(f'Unable to fetch url: {unable_to_fetch_url}\n')
    logger.info(f'Skipped due to headline: {skipped_due_to_headline}\n')
    logger.info(f'Skipped due to content: {skipped_due_to_content}\n')
    logger.info(f'Skipped due to date: {skipped_due_to_date}\n')
    logger.info(f'Unable to download image: {unable_to_download_pdf}\n')
    logger.info(f'Processing finished in {time.time() - start_time} seconds.\n')
# Out:
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000021.pdf
# Defense Chronology
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000021.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000022.pdf
# New Domains
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000022.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000023.pdf
# 50 Years of the Defense of Japan
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02000023.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010201.pdf
# The United States
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010201.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010202.pdf
# China
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010202.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010203.pdf
# Korean Peninsula
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010203.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010204.pdf
# Russia
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010204.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010205.pdf
# Oceania
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010205.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010206.pdf
# Southeast Asia
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010206.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010207.pdf
# South Asia
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010207.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010208.pdf
# Europe
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010208.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010209.pdf
# Middle East, North Africa, and Other Regions
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010209.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010301.pdf
# Trends Concerning Military Science and Technology
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010301.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010302.pdf
# Trends in Space Domain
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010302.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010303.pdf
# Trends in Cyber Domain
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010303.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010304.pdf
# Trends in Electromagnetic Domain
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010304.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010305.pdf
# Developments regarding the Novel Coronavirus Disease (COVID-19)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010305.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010306.pdf
# Maritime Trends
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010306.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010307.pdf
# Transfer and Proliferation of Weapons of Mass Destruction (WMDs)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010307.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010308.pdf
# Trends in International Terrorism
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02010308.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020101.pdf
# Measures to Ensure Japan’s Security
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020101.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020102.pdf
# Constitution and the Basis of Defense Policy
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020102.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020201.pdf
# National Security Council
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020201.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020202.pdf
# Organization of the MOD/Self-Defense Forces (SDF)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020202.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020301.pdf
# Outline of the National Security Strategy (NSS)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020301.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020302.pdf
# Outline of NDPG
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020302.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020303.pdf
# Outline of the MTDP (FY2019?FY2023)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020303.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020401.pdf
# Build-Up of Defense Capability in FY2020
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020401.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020402.pdf
# Defense-Related Expenditures
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020402.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020501.pdf
# Framework for Activities of the SDF and Others
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020501.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020502.pdf
# SDF Activities since Enforcement of Legislation for Peace and Security
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02020502.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030101.pdf
# Response from Peacetime to Grey Zone Situations
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030101.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030102.pdf
# Defense of Japan including its Remote Islands
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030102.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030103.pdf
# Responses in the Domains of Space, Cyberspace and Electromagnetic Spectrum
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030103.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030104.pdf
# Efforts of the MOD/SDF in response to the Spread of Novel Coronavirus Disease (COVID-19)
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030104.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030105.pdf
# Response to Large-Scale Disasters, etc.
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030105.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030106.pdf
# Information Gathering Activities for Ensuring the Safety of Japan-related Vessels in the Middle East
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030106.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030201.pdf
# Outline of the Japan-U.S. Security Arrangements
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030201.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030202.pdf
# Strengthening Ability of Japan-U.S. Alliance to Deter and Counter Threats
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030202.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030203.pdf
# Strengthening and Expanding Cooperation in a Wide Range of Areas
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030203.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030204.pdf
# Steady Implementation of Measures Concerning the USFJ
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030204.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030301.pdf
# Strategic Promotion of Multi-Faceted and Multi-Layered Defense Cooperation
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030301.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030302.pdf
# Ensuring Maritime Security
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030302.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030303.pdf
# Cooperation in Use of Space and Cyber Domains
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030303.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030304.pdf
# Initiatives for Arms Control, Disarmament and Non-Proliferation
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030304.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030305.pdf
# Efforts to Support International Peace Cooperation Activities
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02030305.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040101.pdf
# Reinforcing Human Resource Base
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040101.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040102.pdf
# Further Promotion of Work-Life Balance and Women’s Participation
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040102.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040201.pdf
# Reviewing Equipment Structure
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040201.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040202.pdf
# Reinforcing Technology Base
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040202.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040203.pdf
# Optimizing Equipment Procurement
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040203.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040204.pdf
# Strengthening Defense Industrial Base
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040204.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040205.pdf
# Defense Equipment and Technology Cooperation
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040205.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040401.pdf
# SDF Training
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040401.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040402.pdf
# Enhancement of Medical Functions
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040402.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040501.pdf
# Collaboration with Local Communities
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040501.pdf
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040502.pdf
# Public Relations Activities, Public Records and Archives Management, Information Disclosure, and Related Activities
# https://www.mod.go.jp/e/publ/w_paper/wp2020/pdf/R02040502.pdf
